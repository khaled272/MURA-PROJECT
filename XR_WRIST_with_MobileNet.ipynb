# %%
# This code is to train a model to detect the abnormality 
# in the wrist xray.

# %%
import os
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation,Dropout
from keras import regularizers
from keras.optimizers import Adam, Adadelta
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_path = 'XR_WRIST/train'
valid_path = 'XR_WRIST/valid'
test_path = 'XR_WRIST/test'

# %%
# Generate batches of tensor image data with real-time data augmentation. The data will be looped over (in batches)
train_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 7745 images belonging to 2 classes.
# Found 993 images belonging to 2 classes.
# Found 659 images belonging to 2 classes.

# %%
# Confusion matrix function
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Set the model to be = MobileNet with trained weights transfered.
mobile = keras.applications.mobilenet.MobileNet()

# %%
# Modify the structure by removing the last 5 layers 
# and then adding and two dense layers with relu activation
# dropout and one dense layer without dropout 
# and output layer with 7 neurons and softmax activation
x = mobile.layers[-6].output
predictions = Dense(2, activation='softmax')(x)
model2 = Model(inputs=mobile.input, outputs=predictions)
x = model2.layers[-2].output
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)

predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=model.input, outputs=predictions)

# %%
# verify changes
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 1024)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 5,590,978
# Trainable params: 5,569,090
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# This cell and the one below is to control which 
# layers to be freezed and which to be trained
for layer in model.layers[:]:
    layer.trainable = False

# %%
for layer in model.layers[:-7]:
    layer.trainable = True

# %%
# compile the model
model.compile(Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# start training
model.fit_generator(train_batches, steps_per_epoch=163, 
                    validation_data=valid_batches, validation_steps=993, epochs=10, verbose=2)
# Out:
# Epoch 1/10
#  - 34s - loss: 0.2367 - acc: 0.9233 - val_loss: 0.3168 - val_acc: 0.9158
# Epoch 2/10
#  - 34s - loss: 0.2299 - acc: 0.9294 - val_loss: 0.2835 - val_acc: 0.9160
# Epoch 3/10
#  - 34s - loss: 0.2287 - acc: 0.9313 - val_loss: 0.2905 - val_acc: 0.9078
# Epoch 4/10
#  - 34s - loss: 0.2741 - acc: 0.9037 - val_loss: 0.2858 - val_acc: 0.9106
# Epoch 5/10
#  - 34s - loss: 0.2636 - acc: 0.9178 - val_loss: 0.2541 - val_acc: 0.9153
# Epoch 6/10
#  - 34s - loss: 0.1767 - acc: 0.9417 - val_loss: 0.3112 - val_acc: 0.8983
# Epoch 7/10
#  - 34s - loss: 0.2009 - acc: 0.9313 - val_loss: 0.2789 - val_acc: 0.9083
# Epoch 8/10
#  - 34s - loss: 0.1981 - acc: 0.9374 - val_loss: 0.3574 - val_acc: 0.8792
# Epoch 9/10
#  - 34s - loss: 0.2366 - acc: 0.9252 - val_loss: 0.2883 - val_acc: 0.9015
# Epoch 10/10
#  - 34s - loss: 0.1925 - acc: 0.9374 - val_loss: 0.2855 - val_acc: 0.9014

# %%
# Get the labels
test_labels = test_batches.classes
# Rest the cursor to the start of the test set befor testing
test_batches.reset()

# %%
# Test the model on the test set
predictions = model.predict_generator(test_batches, steps=66, verbose=1)
# Out:
# 66/66 [==============================] - 2s 24ms/step

# %%
# Prepare the confusion matrix
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
# check the labels with thier indices
test_batches.class_indices
# Out:
# {'negative': 0, 'positive': 1}

# %%
# show the confusion matrix
cm_plot_labels = ['negative','positive']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[330  34]
#  [ 55 240]]

# %%
# The overall accuracy of the model
print('Accuracy= ',(cm[0][0]+cm[1][1])*100/(cm[0][0]+cm[1][1]+cm[0][1]+cm[1][0]),' %')
# Out:
# Accuracy=  86.49468892261001  %

# %%
# Prepare the images for (TEST ON STUDY LEVEL)
def prepare_image(file):
    img_path = ''
    img = image.load_img(file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# Test the model on the study level:
# 1. all the images in one study are gettting predicted indivisually
# 2. the arithmatic mean of all the images in one study is taken to
#    produce the prediction on the study level

path='MURA-v1.1/valid/XR_WRIST/'
img_count=0
img_pos=0
img_neg=0
img_fpos=0
img_fneg=0
true_pos=0
true_neg=0
false_pos=0
false_neg=0
false_pos_lst=[]
false_neg_lst=[]
templst=[]

for patient in os.listdir(path):
    for study in os.listdir(path+patient):
        total_pred=0
        for img in os.listdir(path+patient+'/'+study):
            img_count +=1
            print(path+patient+'/'+study+'/'+img)
            preprocessed_image = prepare_image(path+patient+'/'+study+'/'+img)
            predictions = model.predict(preprocessed_image)
            if predictions[0][1]>0.5 and study.split('_')[1] == 'positive':
                img_pos += 1
            elif predictions[0][1]<=0.5 and study.split('_')[1] == 'negative':
                img_neg += 1
            elif predictions[0][1]>0.5 and study.split('_')[1] != 'positive':
                img_fpos += 1
            else:
                img_fneg += 1
        
            total_pred += predictions[0][1]
        avg_pred = total_pred/len(os.listdir(path+patient+'/'+study))
        if avg_pred <= 0.5:
            abnorm_pred='negative'
        else:
            abnorm_pred='positive'
            
        if abnorm_pred == study.split('_')[1] == 'positive':
            true_pos +=1
        elif abnorm_pred == study.split('_')[1] == 'negative':
            true_neg +=1
        elif abnorm_pred != study.split('_')[1] == 'negative':
            false_pos +=1
            false_pos_lst.append(patient+'/'+study)
        else:
            false_neg +=1
            false_neg_lst.append(patient+'/'+study)
# Out:
# MURA-v1.1/valid/XR_WRIST/patient11284/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11284/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11240/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11240/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11240/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11367/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11367/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11367/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11221/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11221/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11221/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11219/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11219/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11219/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11219/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study2_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11267/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11185/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11185/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11185/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11185/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11299/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11268/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11268/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11268/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11277/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11277/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11277/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11243/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11243/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11243/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11324/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11324/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11324/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11234/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11234/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11234/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11315/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11315/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11228/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11228/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11228/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11228/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11228/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11269/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11269/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11269/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11269/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11305/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11305/study2_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11305/study2_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11305/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11305/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11208/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11208/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11208/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11259/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11259/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11259/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11260/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11260/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11260/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11260/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11338/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11338/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11187/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11242/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11242/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11242/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11323/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11323/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11323/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study2_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11212/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11309/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11309/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11341/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11341/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11341/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11328/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11328/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11328/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11258/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11258/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11258/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11316/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11316/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11276/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11276/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11276/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11378/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11387/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11387/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11387/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11286/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11384/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11384/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11384/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient
study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11297/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11297/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11296/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11296/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11285/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11291/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11291/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11291/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study2_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11347/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11359/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11250/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11250/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11250/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11250/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11360/study1_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11360/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11360/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11360/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11237/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11237/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11237/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11203/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11203/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11248/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11248/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11263/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11263/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11263/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11354/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11354/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11354/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study3_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study3_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study3_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study4_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study4_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study4_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11272/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11312/study1_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11312/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11312/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11312/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11273/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11273/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11273/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11273/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11320/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11320/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11320/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11211/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11211/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11211/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11281/study1_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11281/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11281/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11281/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11198/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11198/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11195/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11195/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11195/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11325/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11325/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11325/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11232/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11232/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11232/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11232/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11279/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11279/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11279/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11247/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11247/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11247/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11247/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study3_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study3_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study3_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study2_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study2_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study2_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11186/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11383/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11383/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11383/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11271/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11271/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11363/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11363/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11363/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11300/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11300/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11351/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11351/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11351/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11192/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11192/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11192/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11302/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11388/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11388/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11388/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11249/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11249/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11249/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11249/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11245/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11245/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11245/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11345/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11345/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11345/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11331/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11331/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11331/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11381/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11381/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11313/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11313/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11288/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11288/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11254/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11254/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11254/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11254/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study3_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study3_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study3_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study3_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11264/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11369/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11369/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11369/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11386/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11386/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11275/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11275/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11275/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11224/study1_positive/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11224/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11224/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11224/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11295/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11295/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11365/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11365/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11365/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11303/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11303/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11346/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11346/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11229/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11229/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11229/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study3_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study3_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study2_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study2_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study2_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11227/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11376/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11376/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11307/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11262/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11262/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11262/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11202/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11202/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11202/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11205/study1_positive/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11205/study1_positive/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11205/study1_positive/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11379/study1_negative/image4.png
# MURA-v1.1/valid/XR_WRIST/patient11379/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11379/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11379/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11375/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11375/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11375/study1_negative/image1.png
# MURA-v1.1/valid/XR_WRIST/patient11366/study1_negative/image3.png
# MURA-v1.1/valid/XR_WRIST/patient11366/study1_negative/image2.png
# MURA-v1.1/valid/XR_WRIST/patient11366/study1_negative/image1.png

# %%
## Testing on the original MURA Dataset 

print('Total number of images = ',img_count)
print('True Positive = ',img_pos)
print('True Nigative= ',img_neg)
print('False Positive = ',img_fpos)
print('False Nigative= ',img_fneg)
print('Accuracy on IMAGE level =', 100*(img_pos+img_neg)/(img_pos+img_neg+img_fpos+img_fneg))
print('')
print('True Positive = ',true_pos)
print('True Nigative= ',true_neg)
print('False Positive = ',false_pos)
print('False Nigative= ',false_neg)
print('Accuracy on STUDY level =', 100*(true_neg+true_pos)/(true_neg+true_pos+false_neg+false_pos))
# Out:
# Total number of images =  659
# True Positive =  240
# True Nigative=  330
# False Positive =  34
# False Nigative=  55
# Accuracy on IMAGE level = 86.49468892261001
#
# True Positive =  79
# True Nigative=  133
# False Positive =  7
# False Nigative=  18
# Accuracy on STUDY level = 89.45147679324894

# %%
#### SAVE MODEL ####

model.save_weights("models/XR_WRIST.h5")

#Save the model architecture
with open('models/architecture_XR_WRIST.json', 'w') as f:
    f.write(model.to_json())
