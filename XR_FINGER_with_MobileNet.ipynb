# %%
# This code is to train a model to detect the abnormality 
# in the finger xray.

# %%
import os
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation,Dropout
from keras import regularizers
from keras.optimizers import Adam, Adadelta
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_path = 'XR_FINGER/train'
valid_path = 'XR_FINGER/valid'
test_path = 'XR_FINGER/test'

# %%
# Generate batches of tensor image data with real-time data augmentation. The data will be looped over (in batches)
train_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 4758 images belonging to 2 classes.
# Found 578 images belonging to 2 classes.
# Found 461 images belonging to 2 classes.

# %%
# Confusion matrix function
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Set the model to be = MobileNet with trained weights transfered.
mobile = keras.applications.mobilenet.MobileNet()

# %%
# Modify the structure by removing the last 5 layers 
# and then adding and two dense layers with relu activation
# dropout and one dense layer without dropout 
# and output layer with 7 neurons and softmax activation
x = mobile.layers[-6].output
predictions = Dense(2, activation='softmax')(x)
model = Model(inputs=mobile.input, outputs=predictions)
x = model.layers[-2].output
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)

predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=model.input, outputs=predictions)

# %%
# verify changes
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 5,590,978
# Trainable params: 5,569,090
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# This cell and the one below is to control which 
# layers to be freezed and which to be trained
for layer in model.layers[:]:
    layer.trainable = False

# %%
for layer in model.layers[:-6]:
    layer.trainable = True

# %%
# compile the model
model.compile(Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# start training
model.fit_generator(train_batches, steps_per_epoch=163, 
                    validation_data=valid_batches, validation_steps=578, epochs=10, verbose=2)
# Out:
# Epoch 1/10
#  - 21s - loss: 0.6631 - acc: 0.6393 - val_loss: 0.6495 - val_acc: 0.6486
# Epoch 2/10
#  - 18s - loss: 0.6412 - acc: 0.6528 - val_loss: 0.5550 - val_acc: 0.7271
# Epoch 3/10
#  - 18s - loss: 0.6287 - acc: 0.6663 - val_loss: 0.5684 - val_acc: 0.6991
# Epoch 4/10
#  - 18s - loss: 0.5706 - acc: 0.6975 - val_loss: 0.6022 - val_acc: 0.6727
# Epoch 5/10
#  - 18s - loss: 0.5437 - acc: 0.7337 - val_loss: 0.5615 - val_acc: 0.7106
# Epoch 6/10
#  - 18s - loss: 0.5689 - acc: 0.6991 - val_loss: 0.8053 - val_acc: 0.6493
# Epoch 7/10
#  - 18s - loss: 0.5353 - acc: 0.7423 - val_loss: 0.8479 - val_acc: 0.6300
# Epoch 8/10
#  - 18s - loss: 0.5113 - acc: 0.7540 - val_loss: 0.7923 - val_acc: 0.6851
# Epoch 9/10
#  - 18s - loss: 0.5222 - acc: 0.7471 - val_loss: 0.5290 - val_acc: 0.7243
# Epoch 10/10
#  - 18s - loss: 0.5032 - acc: 0.7528 - val_loss: 0.5523 - val_acc: 0.7161

# %%
# Get the labels
test_labels = test_batches.classes
# Rest the cursor to the start of the test set befor testing
test_batches.reset()

# %%
# Test the model on the test set
predictions = model.predict_generator(test_batches, steps=47, verbose=1)
# Out:
# 47/47 [==============================] - 1s 31ms/step

# %%
# Prepare the confusion matrix
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
# check the labels with thier indices
test_batches.class_indices
# Out:
# {'negative': 0, 'positive': 1}

# %%
# show the confusion matrix
cm_plot_labels = ['negative','positive']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[166  48]
#  [ 78 169]]

# %%
# The overall accuracy of the model
print('Accuracy= ',(cm[0][0]+cm[1][1])*100/(cm[0][0]+cm[1][1]+cm[0][1]+cm[1][0]),' %')
# Out:
# Accuracy=  72.66811279826464  %

# %%
# Prepare the images for (TEST ON STUDY LEVEL)
def prepare_image(file):
    img_path = ''
    img = image.load_img(file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# Test the model on the study level:
# 1. all the images in one study are gettting predicted indivisually
# 2. the arithmatic mean of all the images in one study is taken to
#    produce the prediction on the study level

path='MURA-v1.1/valid/XR_FINGER/'
img_count=0
img_pos=0
img_neg=0
img_fpos=0
img_fneg=0
true_pos=0
true_neg=0
false_pos=0
false_neg=0
false_pos_lst=[]
false_neg_lst=[]
templst=[]

for patient in os.listdir(path):
    for study in os.listdir(path+patient):
        total_pred=0
        for img in os.listdir(path+patient+'/'+study):
            img_count +=1
            print(path+patient+'/'+study+'/'+img)
            preprocessed_image = prepare_image(path+patient+'/'+study+'/'+img)
            predictions = model.predict(preprocessed_image)
            if predictions[0][1]>0.5 and study.split('_')[1] == 'positive':
                img_pos += 1
            elif predictions[0][1]<=0.5 and study.split('_')[1] == 'negative':
                img_neg += 1
            elif predictions[0][1]>0.5 and study.split('_')[1] != 'positive':
                img_fpos += 1
            else:
                img_fneg += 1
        
            total_pred += predictions[0][1]
        avg_pred = total_pred/len(os.listdir(path+patient+'/'+study))
        if avg_pred <= 0.5:
            abnorm_pred='negative'
        else:
            abnorm_pred='positive'
            
        if abnorm_pred == study.split('_')[1] == 'positive':
            true_pos +=1
        elif abnorm_pred == study.split('_')[1] == 'negative':
            true_neg +=1
        elif abnorm_pred != study.split('_')[1] == 'negative':
            false_pos +=1
            false_pos_lst.append(patient+'/'+study)
        else:
            false_neg +=1
            false_neg_lst.append(patient+'/'+study)
# Out:
# MURA-v1.1/valid/XR_FINGER/patient11581/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11581/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11581/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11419/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11419/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11419/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11619/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11619/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11619/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11909/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11909/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11909/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11420/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11420/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11420/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11420/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11927/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11927/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11927/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11234/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11315/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11919/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11919/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11919/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11898/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11898/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11898/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11884/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11884/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11884/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11466/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11466/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11466/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11910/study1_positive/image5.png
# MURA-v1.1/valid/XR_FINGER/patient11910/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11910/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11910/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11910/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11966/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11966/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11966/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11917/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11917/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11917/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11917/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11338/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11338/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11338/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11936/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11936/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11936/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11954/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11954/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11954/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11883/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11883/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11883/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11947/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11947/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11947/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11886/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11341/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11341/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11341/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11897/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11897/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11897/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11410/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11410/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11410/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11906/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11906/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11906/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11906/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11276/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11276/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11276/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11940/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11940/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11940/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11956/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11477/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11477/study2_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11477/study2_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11477/study2_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11253/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11253/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11253/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11939/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11939/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11939/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11513/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11955/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11964/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11964/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11932/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11932/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11932/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11723/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11723/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11723/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11888/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11888/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11888/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11738/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11738/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11738/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11908/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11908/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11908/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11859/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11859/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11859/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11951/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11951/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11951/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11904/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11904/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11904/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11904/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11416/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11416/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11416/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11606/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11711/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11920/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11920/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11920/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11446/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11446/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11446/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11901/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11901/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11901/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11855/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11894/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11894/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11578/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11578/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11578/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11578/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study2_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study2_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study2_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11561/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11887/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11887/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11887/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11385/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11385/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11385/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11925/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11348/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11922/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11934/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11934/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11934/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study2_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study2_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11946/study2_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11569/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11569/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11569/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11892/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11892/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11892/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11916/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11916/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11921/study1_positive/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11921/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11921/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11921/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11329/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11329/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11329/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11220/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11220/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11220/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11967/study1_negative/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11967/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11967/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11967/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11949/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11614/study1_negative/image4.png
# MURA-v1.1/valid/XR_FINGER/patient11614/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11614/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11614/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11948/study1_negative/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11948/study1_negative/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11948/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11667/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11667/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11667/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11397/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11397/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11397/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11885/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11885/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11885/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11957/study1_negative/image1.png
# MURA-v1.1/valid/XR_FINGER/patient11913/study1_positive/image3.png
# MURA-v1.1/valid/XR_FINGER/patient11913/study1_positive/image2.png
# MURA-v1.1/valid/XR_FINGER/patient11913/study1_positive/image1.png
# MURA-v1.1/valid/XR_FINGER/patient