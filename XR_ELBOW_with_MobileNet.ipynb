# %%
# This code is to train a model to detect the abnormality 
# in the wrist xray.

# %%
import os
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation,Dropout
from keras import regularizers
from keras.optimizers import Adam, Adadelta
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_path = 'XR_ELBOW/train'
valid_path = 'XR_ELBOW/valid'
test_path = 'XR_ELBOW/test'

# %%
# Generate batches of tensor image data with real-time data augmentation. The data will be looped over (in batches)
train_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 4317 images belonging to 2 classes.
# Found 539 images belonging to 2 classes.
# Found 465 images belonging to 2 classes.

# %%
# Confusion matrix function
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Set the model to be = MobileNet with trained weights transfered.
mobile = keras.applications.mobilenet.MobileNet()

# %%
# Modify the structure by removing the last 5 layers 
# and then adding and two dense layers with relu activation
# dropout and one dense layer without dropout 
# and output layer with 7 neurons and softmax activation
x = mobile.layers[-6].output
predictions = Dense(2, activation='softmax')(x)
model = Model(inputs=mobile.input, outputs=predictions)
x = model.layers[-2].output
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)

predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=model.input, outputs=predictions)

# %%
# verify changes
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 5,590,978
# Trainable params: 3,206,976
# Non-trainable params: 2,384,002
# _________________________________________________________________

# %%
# This cell and the one below is to control which 
# layers to be freezed and which to be trained
for layer in model.layers[:]:
    layer.trainable = False

# %%
for layer in model.layers[:-6]:
    layer.trainable = True

# %%
# compile the model
model.compile(Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# start training
model.fit_generator(train_batches, steps_per_epoch=163, 
                    validation_data=valid_batches, validation_steps=539, epochs=10, verbose=2)
# Out:
# Epoch 1/10
#  - 25s - loss: 0.6623 - acc: 0.6724 - val_loss: 0.8118 - val_acc: 0.6502
# Epoch 2/10
#  - 19s - loss: 0.5230 - acc: 0.7566 - val_loss: 0.4901 - val_acc: 0.7730
# Epoch 3/10
#  - 19s - loss: 0.5091 - acc: 0.7601 - val_loss: 0.4993 - val_acc: 0.7954
# Epoch 4/10
#  - 19s - loss: 0.4890 - acc: 0.7785 - val_loss: 0.5233 - val_acc: 0.7467
# Epoch 5/10
#  - 19s - loss: 0.4669 - acc: 0.7946 - val_loss: 0.5002 - val_acc: 0.8022
# Epoch 6/10
#  - 19s - loss: 0.4640 - acc: 0.8018 - val_loss: 0.5530 - val_acc: 0.7545
# Epoch 7/10
#  - 19s - loss: 0.5058 - acc: 0.7628 - val_loss: 0.4938 - val_acc: 0.7807
# Epoch 8/10
#  - 19s - loss: 0.4333 - acc: 0.8160 - val_loss: 0.4729 - val_acc: 0.7673
# Epoch 9/10
#  - 19s - loss: 0.4301 - acc: 0.8172 - val_loss: 0.4460 - val_acc: 0.7998
# Epoch 10/10
#  - 19s - loss: 0.4169 - acc: 0.8120 - val_loss: 0.4676 - val_acc: 0.7924

# %%
# Get the labels
test_labels = test_batches.classes
# Rest the cursor to the start of the test set befor testing
test_batches.reset()

# %%
# Test the model on the test set
predictions = model.predict_generator(test_batches, steps=47, verbose=1)
# Out:
# 47/47 [==============================] - 1s 26ms/step

# %%
# Prepare the confusion matrix
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
# check the labels with thier indices
test_batches.class_indices
# Out:
# {'negative': 0, 'positive': 1}

# %%
# show the confusion matrix
cm_plot_labels = ['negative','positive']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[228   7]
#  [ 71 159]]

# %%
# The overall accuracy of the model
print('Accuracy= ',(cm[0][0]+cm[1][1])*100/(cm[0][0]+cm[1][1]+cm[0][1]+cm[1][0]),' %')
# Out:
# Accuracy=  83.2258064516129  %

# %%
# Prepare the images for (TEST ON STUDY LEVEL)
def prepare_image(file):
    img_path = ''
    img = image.load_img(file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# Test the model on the study level:
# 1. all the images in one study are gettting predicted indivisually
# 2. the arithmatic mean of all the images in one study is taken to
#    produce the prediction on the study level

path='MURA-v1.1/valid/XR_ELBOW/'
img_count=0
img_pos=0
img_neg=0
img_fpos=0
img_fneg=0
true_pos=0
true_neg=0
false_pos=0
false_neg=0
false_pos_lst=[]
false_neg_lst=[]
templst=[]

for patient in os.listdir(path):
    for study in os.listdir(path+patient):
        total_pred=0
        for img in os.listdir(path+patient+'/'+study):if part == 'FINGER': 
        return finger_predict(image_file)
    if part == 'FOREARM': 
        return forearm_predict(image_file)
    if part == 'HAND': 
        return hand_predict(image_file)
    if part == 'HUMERUS': 
        return humerus_predict(image_file)
    if part == 'SHOULDER': 
        return shoulder_predict(image_file)
    if part == 'WRIST': 
        return wrist_predict(image_file)
            img_count +=1
            print(path+patient+'/'+study+'/'+img)
            preprocessed_image = prepare_image(path+patient+'/'+study+'/'+img)
            predictions = model.predict(preprocessed_image)
            if predictions[0][1]>0.5 and study.split('_')[1] == 'positive':
                img_pos += 1
            elif predictions[0][1]<=0.5 and study.split('_')[1] == 'negative':
                img_neg += 1
            elif predictions[0][1]>0.5 and study.split('_')[1] != 'positive':
                img_fpos += 1
            else:
                img_fneg += 1
        
            total_pred += predictions[0][1]
        avg_pred = total_pred/len(os.listdir(path+patient+'/'+study))
        if avg_pred <= 0.5:
            abnorm_pred='negative'
        else:
            abnorm_pred='positive'
            
        if abnorm_pred == study.split('_')[1] == 'positive':
            true_pos +=1
        elif abnorm_pred == study.split('_')[1] == 'negative':
            true_neg +=1
        elif abnorm_pred != study.split('_')[1] == 'negative':
            false_pos +=1
            false_pos_lst.append(patient+'/'+study)
        else:
            false_neg +=1
            false_neg_lst.append(patient+'/'+study)
# Out:
# MURA-v1.1/valid/XR_ELBOW/patient11823/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11823/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11763/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11763/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11875/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11875/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11764/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11764/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11764/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11764/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11764/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11414/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11414/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11869/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11869/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11878/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11878/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11802/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11802/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11802/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11802/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11802/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11243/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11243/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11820/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11820/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11820/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11820/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11820/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11708/study1_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11708/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11708/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11708/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11819/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11819/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11868/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11868/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11466/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11466/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11466/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11259/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11259/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11806/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11806/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study1_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study2_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study2_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study2_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11338/study2_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11835/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11835/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11824/study2_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11824/study2_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11824/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11824/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11879/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11879/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11478/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11478/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11860/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11860/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image7.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image8.png
# MURA-v1.1/valid/XR_ELBOW/patient11830/study1_positive/image6.png
# MURA-v1.1/valid/XR_ELBOW/patient11822/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11822/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11822/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11838/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11838/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11838/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11588/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11588/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11536/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11536/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11876/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11876/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11870/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11870/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11870/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11859/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11859/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11858/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11858/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11389/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11389/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11389/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11389/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11606/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11606/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11821/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11821/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11821/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11711/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11711/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11711/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11855/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11855/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11855/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11828/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11828/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11828/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11797/study1_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11797/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11797/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11797/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11326/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11326/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11326/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11326/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11837/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11837/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11837/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11417/study2_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11417/study2_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11417/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11417/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11222/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11443/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11443/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11836/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11836/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11836/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11836/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11836/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11862/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11862/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11862/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11651/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11651/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11832/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11832/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11832/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11832/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11342/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11342/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11521/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11521/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11586/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11586/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11569/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11569/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11569/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11783/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11783/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11783/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11217/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11217/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11217/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11659/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11659/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11659/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11777/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11777/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11238/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11238/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11877/study1_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11877/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11877/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11877/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11856/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11856/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11856/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study2_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study2_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study2_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11390/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11430/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11430/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11430/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11430/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11430/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11204/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11204/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11287/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11287/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11287/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11793/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11793/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11793/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11793/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11793/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11818/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11818/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11818/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11818/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11818/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11283/study1_negative/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11283/study1_negative/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11283/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11283/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11866/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11866/study1_negative/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image5.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image4.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image3.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image1.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image7.png
# MURA-v1.1/valid/XR_ELBOW/patient11831/study1_positive/image6.png
# MURA-v1.1/valid/XR_ELBOW/patient11568/study1_negative/image2.png
# MURA-v1.1/valid/XR_ELBOW/patient