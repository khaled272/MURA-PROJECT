# %%
# This code is to train a model to detect the abnormality 
# in the hand xray.

# %%
import os
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation,Dropout
from keras import regularizers
from keras.optimizers import Adam, Adadelta
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_path = 'XR_HAND/train'
valid_path = 'XR_HAND/valid'
test_path = 'XR_HAND/test'

# %%
# Generate batches of tensor image data with real-time data augmentation. The data will be looped over (in batches)
train_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(
    test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 5413 images belonging to 2 classes.
# Found 590 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.

# %%
# Confusion matrix function
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Set the model to be = MobileNet with trained weights transfered.
mobile = keras.applications.mobilenet.MobileNet()

# %%
# Modify the structure by removing the last 5 layers 
# and then adding and two dense layers with relu activation
# dropout and one dense layer without dropout 
# and output layer with 7 neurons and softmax activation
x = mobile.layers[-6].output
predictions = Dense(2, activation='softmax')(x)
model = Model(inputs=mobile.input, outputs=predictions)
x = model.layers[-2].output
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)

predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=model.input, outputs=predictions)

# %%
# verify changes
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 5,590,978
# Trainable params: 5,569,090
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# This cell and the one below is to control which 
# layers to be freezed and which to be trained
for layer in model.layers[:]:
    layer.trainable = True

# %%
for layer in model.layers[:-2]:
    layer.trainable = False

# %%
# compile the model
model.compile(Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# start training
model.fit_generator(train_batches, steps_per_epoch=163, 
                    validation_data=valid_batches, validation_steps=590, epochs=10, verbose=2)
# Out:
# Epoch 1/10
#  - 19s - loss: 0.6102 - acc: 0.7153 - val_loss: 0.5917 - val_acc: 0.7156
# Epoch 2/10
#  - 18s - loss: 0.5779 - acc: 0.7374 - val_loss: 0.6006 - val_acc: 0.7178
# Epoch 3/10
#  - 17s - loss: 0.5684 - acc: 0.7387 - val_loss: 0.5986 - val_acc: 0.6997
# Epoch 4/10
#  - 18s - loss: 0.5655 - acc: 0.7397 - val_loss: 0.5931 - val_acc: 0.7154
# Epoch 5/10
#  - 17s - loss: 0.5687 - acc: 0.7405 - val_loss: 0.6150 - val_acc: 0.7005
# Epoch 6/10
#  - 18s - loss: 0.5716 - acc: 0.7405 - val_loss: 0.5962 - val_acc: 0.7019
# Epoch 7/10
#  - 18s - loss: 0.5693 - acc: 0.7374 - val_loss: 0.5930 - val_acc: 0.7212
# Epoch 8/10
#  - 17s - loss: 0.5733 - acc: 0.7405 - val_loss: 0.6115 - val_acc: 0.6795
# Epoch 9/10
#  - 18s - loss: 0.5648 - acc: 0.7393 - val_loss: 0.5916 - val_acc: 0.7144
# Epoch 10/10
#  - 17s - loss: 0.5560 - acc: 0.7464 - val_loss: 0.5913 - val_acc: 0.7139

# %%
# Get the labels
test_labels = test_batches.classes
# Rest the cursor to the start of the test set befor testing
test_batches.reset()

# %%
# Test the model on the test set
predictions = model.predict_generator(test_batches, steps=46, verbose=1)
# Out:
# 46/46 [==============================] - 2s 37ms/step

# %%
# Prepare the confusion matrix
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
# check the labels with thier indices
test_batches.class_indices
# Out:
# {'negative': 0, 'positive': 1}

# %%
# show the confusion matrix
cm_plot_labels = ['negative','positive']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[224  47]
#  [ 87 102]]

# %%
# The overall accuracy of the model
print('Accuracy= ',(cm[0][0]+cm[1][1])*100/(cm[0][0]+cm[1][1]+cm[0][1]+cm[1][0]),' %')
# Out:
# Accuracy=  70.8695652173913  %

# %%
# Prepare the images for (TEST ON STUDY LEVEL)
def prepare_image(file):
    img_path = ''
    img = image.load_img(file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# Test the model on the study level:
# 1. all the images in one study are gettting predicted indivisually
# 2. the arithmatic mean of all the images in one study is taken to
#    produce the prediction on the study level

path='MURA-v1.1/valid/XR_HAND/'
img_count=0
img_pos=0
img_neg=0
img_fpos=0
img_fneg=0
true_pos=0
true_neg=0
false_pos=0
false_neg=0
false_pos_lst=[]
false_neg_lst=[]
templst=[]

for patient in os.listdir(path):
    for study in os.listdir(path+patient):
        total_pred=0
        for img in os.listdir(path+patient+'/'+study):
            img_count +=1
            print(path+patient+'/'+study+'/'+img)
            preprocessed_image = prepare_image(path+patient+'/'+study+'/'+img)
            predictions = model.predict(preprocessed_image)
            if predictions[0][1]>0.5 and study.split('_')[1] == 'positive':
                img_pos += 1
            elif predictions[0][1]<=0.5 and study.split('_')[1] == 'negative':
                img_neg += 1
            elif predictions[0][1]>0.5 and study.split('_')[1] != 'positive':
                img_fpos += 1
            else:
                img_fneg += 1
        
            total_pred += predictions[0][1]
        avg_pred = total_pred/len(os.listdir(path+patient+'/'+study))
        if avg_pred <= 0.5:
            abnorm_pred='negative'
        else:
            abnorm_pred='positive'
            
        if abnorm_pred == study.split('_')[1] == 'positive':
            true_pos +=1
        elif abnorm_pred == study.split('_')[1] == 'negative':
            true_neg +=1
        elif abnorm_pred != study.split('_')[1] == 'negative':
            false_pos +=1
            false_pos_lst.append(patient+'/'+study)
        else:
            false_neg +=1
            false_neg_lst.append(patient+'/'+study)
# Out:
# MURA-v1.1/valid/XR_HAND/patient11581/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11581/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11577/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11577/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11573/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11573/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11240/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11240/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11240/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11503/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11503/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11503/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11406/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11406/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11571/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11571/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11571/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11597/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11597/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11552/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11552/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11552/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11267/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11267/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11267/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11541/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11541/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11541/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11605/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11605/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11605/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11420/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11420/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11584/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11584/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11234/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11234/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11234/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11269/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11269/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11269/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11497/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11497/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11497/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11550/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11550/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11587/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11587/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11587/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11460/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11460/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11460/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11575/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11575/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11575/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11212/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11212/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11212/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11565/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11565/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11531/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11531/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11531/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11558/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11558/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11512/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11512/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11512/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11566/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11566/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11537/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11537/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11562/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11562/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11513/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11513/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11513/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11505/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11505/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11505/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11403/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11588/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11588/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11588/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11483/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11483/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11483/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11499/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11499/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11499/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11536/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11536/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11536/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11549/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11549/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11549/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11607/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11607/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11522/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11522/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11522/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11554/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11554/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11554/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11422/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11422/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11545/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11545/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11545/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11389/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11389/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11389/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11606/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11606/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11606/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11599/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11599/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11293/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11293/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11293/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11216/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11216/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11356/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11356/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11356/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11578/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11578/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11578/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11530/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11530/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11530/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11371/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11371/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11371/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11561/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11561/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11561/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11515/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11515/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11337/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11337/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11517/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11517/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11517/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11348/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11348/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11348/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11567/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11567/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11533/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11533/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11535/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11535/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11535/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11585/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11585/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11255/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11255/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11255/study2_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11255/study2_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11521/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11521/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11521/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11586/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11586/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11586/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11569/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11569/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11569/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11529/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11529/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11529/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11238/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11238/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11238/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11543/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11543/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11543/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11504/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11504/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11336/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11336/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11336/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11510/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11510/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11510/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11484/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11484/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11194/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11194/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11194/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11190/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11190/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11190/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11190/study2_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11190/study2_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11190/study2_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11283/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11283/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11283/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11429/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11429/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11429/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11557/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11557/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11557/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11516/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11516/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11516/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11564/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11564/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11564/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11218/study3_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11218/study3_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11218/study3_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11218/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11218/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11218/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11218/study2_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11218/study2_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11218/study2_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11594/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11594/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11594/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11568/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11568/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11568/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11435/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11435/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient11435/study1_negative/image1.png
# MURA-v1.1/valid/XR_HAND/patient11539/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11539/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11539/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11500/study1_positive/image4.png
# MURA-v1.1/valid/XR_HAND/patient11500/study1_positive/image3.png
# MURA-v1.1/valid/XR_HAND/patient11500/study1_positive/image2.png
# MURA-v1.1/valid/XR_HAND/patient11500/study1_positive/image1.png
# MURA-v1.1/valid/XR_HAND/patient11461/study1_negative/image3.png
# MURA-v1.1/valid/XR_HAND/patient11461/study1_negative/image2.png
# MURA-v1.1/valid/XR_HAND/patient